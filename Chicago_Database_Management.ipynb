# %%
# !pip install ipython-sql

# %%
# %load_ext sql

# %%
# %sql ibm_db_sa://xpn50287:g4gdm7v2cz%5Errxsd@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: xpn50287@BLUDB'

# %%
# %sql SELECT count(*) as num_of_crimes FROM CRIME;
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %%
# %sql SELECT * FROM CRIME limit 10;
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 'FALSE', 'FALSE', 911, 9, 14, 58, '6', 1155838, 1873050, 2004, '02/10/2018 03:50:01 PM', Decimal('41.80744050'), Decimal('-87.70395585'), '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 'FALSE', 'FALSE', 1112, 11, 27, 23, '6', 1152206, 1906127, 2004, '02/28/2018 03:56:25 PM', Decimal('41.89827996'), Decimal('-87.71640551'), '(41.898279962, -87.716405505)'),
# ...

# %%
# %sql SELECT count(*) as Num_of_Arrest FROM CRIME where arrest = 'TRUE';
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('163'),)]

# %%
# %sql SELECT distinct(primary_type) FROM CRIME where location_description = 'GAS STATION';
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('CRIMINAL TRESPASS',), ('NARCOTICS',), ('ROBBERY',), ('THEFT',)]

# %%
# %sql SELECT community_area_name FROM CENSUS where community_area_name like 'B%';
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %%
# %sql SELECT name_of_school, community_area_number FROM SCHOOLS where community_area_number between 10 and 15 order by community_area_number;
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Daniel C Beard Elementary School', 10),
#  ('Edison Park Elementary School', 10),
#  ('John W Garvy Elementary School', 10),
#  ('Norwood Park Elementary School', 10),
#  ('Oriole Park Elementary School', 10),
#  ('Rufus M Hitch Elementary School', 10),
#  ('William Howard Taft High School', 10),
#  ('William J Onahan Elementary School', 10),
#  ('James B Farnsworth Elementary School', 11),
#  ('Jean Baptiste Beaubien Elementary School', 11),
#  ('Edgebrook Elementary School', 12),
#  ('Sauganash Elementary School', 12),
#  ('Wildwood Elementary School', 12),
#  ('Friedrich W von Steuben Metropolitan Science High School', 13),
#  ('Hannah G Solomon Elementary School', 13),
#  ('Mary Gage Peterson Elementary School', 13),
#  ('Northside College Preparatory High School', 13),
#  ('Northside Learning Center High School', 13),
#  ('Albany Park Multicultural Academy', 14),
# ...

# %%
# %sql SELECT avg(safety_score) as avg_safety_score FROM SCHOOLS;
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %%
# %sql SELECT community_area_name, avg(college_enrollment) as avg_college_enrollment FROM SCHOOLS group by community_area_name order by avg_college_enrollment desc limit 5;
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ARCHER HEIGHTS', Decimal('2411.500000')),
#  ('MONTCLARE', Decimal('1317.000000')),
#  ('WEST ELSDON', Decimal('1233.333333')),
#  ('BRIGHTON PARK', Decimal('1205.875000')),
#  ('BELMONT CRAGIN', Decimal('1198.833333'))]

# %%
# %sql SELECT community_area_name, safety_score FROM SCHOOLS where safety_score = (select min(safety_score) from SCHOOLS);
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('WASHINGTON PARK', 1)]

# %%
# %sql SELECT per_capita_income, community_area_name from CENSUS where community_area_number = (select community_area_number from SCHOOLS where safety_score = 1);
# Out:
#  * ibm_db_sa://xpn50287:***@dashdb-txn-sbox-yp-lon02-04.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(13785, 'Washington Park')]
